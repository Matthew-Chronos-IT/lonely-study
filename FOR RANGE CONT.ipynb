# %%
name = input("what is your name ?: ")
cont = int(input("would like how many times to greet the user ?: "))

for i in range(cont):
  print(f"Hello, {name}!")
# Out:
# what is your name ?: Matheus
# would like how many times to greet the user ?: 3
# Hello, Matheus!
# Hello, Matheus!
# Hello, Matheus!

# %%
name = input("what your name ? ")

print(f"hello Mr.(Sr.):, {name}!")
# Out:
# what your name ? gg
# hello Mr.(Sr.):, gg!

# %%
name = input("what your name ?: ")
age = int(input("what your old age ?: "))

print(f"hello Mr.(Sr.): {name}, you are {age} years old. !")
# Out:
# what your name ? matheus
# what your old age? 33
# hello Mr.(Sr.): matheus, you are 33 years old. !
