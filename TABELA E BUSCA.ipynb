# %%
# @title TABELA E BUSCA
fr=["maça", "uva", "abacaxi", "banana", "kiwi"]

print("===== PRIMEIRA LISTA =====")
print(fr[0])
print(fr[1])
print(fr[2])
print(fr[3])
print(fr[4])
print("===== SEGUNDA LISTA =====")
print("PRIMEIRA FRUTA: ", fr[0])
print("SEGUNDA  FRUTA: ", fr[1])

fr.append("laranja")
fr.remove("abacaxi")

print("===== TERCEIRA LISTA =====")
print(fr[0])
print(fr[1])
print(fr[2])
print(fr[3])
print(fr[4])
print("===== QUARTA LISTA =====")
print("fruta removida: abacaxi")
print("fruta adicionada: ", fr[4])
# Out:
# ===== PRIMEIRA LISTA =====
# maça
# uva
# abacaxi
# banana
# kiwi
# ===== SEGUNDA LISTA =====
# PRIMEIRA FRUTA:  maça
# SEGUNDA  FRUTA:  uva
# ===== TERCEIRA LISTA =====
# maça
# uva
# banana
# kiwi
# laranja
# ===== QUARTA LISTA =====
# fruta removida: abacaxi
# fruta adicionada:  laranja
