# %%
# @title CADASTRO DE CARROS
ano=int(input("QUAL O ANO DO CARRO: "))
cor=(input("QUAL A COR DO CARRO: ")) and cor.upper()
val=float(input("QUAL O VALOR DO CARRO: "))

cd=[ano, cor, val]
print("=== DADOS DO CARRO ===")
print("Ano:   ", cd[0] , "\nCor:   ", cd[1] ,"\nValor: ", cd[2] )
print("======================")

# %%
# @title CARTAO DE VISITA
def cartao_de_visita ():
  nome = input("Digite seu nome")
  print("Ola, ", nome, "prazer em ter você aqui !")
  idade =(int(input("Agora digite a sua idade: ")))
  print("Legal, entao voce tem, ", idade,"anos. Agora a proxima pergunta")
  profi= (input("digite a sua profissão: "))
  print("Nossa entao vc é ", profi, "\nAqui esta seu cartao de visita")
  print("\n===== CARTÃO DE VISITAS =====")
  print("Nome: ", nome)
  print("idade: ", idade)
  print("Profissão: ", profi)
  print("==============================")

cartao_de_visita()

# %%
# @title RETUR def
def wc ():
  print("SEJA BEM VINDO A SISTEMA DE CARTÕES METALINK TECHNOLOGIA\n")

def info ():
  nm = input("DIGITE SEU NOME: ")
  idd = int(input("DIGITE A SUA IDADE: "))
  prf = input("DIGITE A SUA PROFISSÃO: ")
  dd = [nm, idd, prf]
  return dd

def dados (dd):
    print("===== CARTAO DE VISITA =====")
    print("Nome: ", dd[0], "\nIdade: ", dd[1], "\nProfissão: ", dd[2])

wc ()
informacoes = info ()
dados(informacoes)
