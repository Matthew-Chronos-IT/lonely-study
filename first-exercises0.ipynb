# %%
print("Hello, world!")
print("Meu nome é Matheus")
print("Estou aprendendo Python!")

print("Nome: Matheus")
print("Idade: 25 anos")
print("Cidade: Limerick")
print("Hobby: Gosto de consertar computadores")
# Out:
# Hello, world!
# Meu nome é Matheus
# Estou aprendendo Python!
# Nome: Matheus
# Idade: 25 anos
# Cidade: Limerick
# Hobby: Gosto de consertar computadores

# %%
print("NOME: Matheus \nIDADE: 25 anos \nCIDADE: Limerick \nHOBBY: Consertar computadores")


print("===== CARTAO DE VISITA===== \nNOME: Matheus \nIDADE: 25 anos \nCIDADE: Limerick \nHOBBY: Consertar computadores")
# Out:
# NOME: Matheus
# IDADE: 25 anos
# CIDADE: Limerick
# HOBBY: Consertar computadores
# ===== CARTAO DE VISITA=====
# NOME: Matheus
# IDADE: 25 anos
# CIDADE: Limerick
# HOBBY: Consertar computadores

# %%
nome = "matheus"
idade = 25
cidade = "Limerick"
hobby = "consertar computadores"

print("===== CARTAO DE VISITA=====\n")
print("\n Nome:", nome)
print("\n idade:", idade)
print("\n cidade:", cidade)
print("\n hobby:", hobby)
print("\n obrigado chat gpt por me ensinar, i love you s2")
# Out:
# ===== CARTAO DE VISITA=====
#
#
#  Nome: matheus
#
#  idade: 25
#
#  cidade: Limerick
#
#  hobby: consertar computadores
#
#  obrigado chat gpt por me ensinar, i love you s2

# %%
nome = str(input("digite seu nome:  "))
idade = int(input("digite sua idade:  "))
altura = float(input("digite sua altura:  "))
cidade = str(input("digite sua cidade:  "))
hobby = str(input("qual é seu hobby:  "))
"\n"
print("===== CARTAO DE VISITA =====\nNome: ", nome,"\nIdade: ", idade,"\nAltura: ",
      altura,"\nCidade: ", cidade,"\nHobby: ", hobby)
# Out:
# digite seu nome:  mm
# digite sua idade:  12
# digite sua altura:  12
# digite sua cidade:  wsdf
# qual é seu hobby:  sdf
# ===== CARTAO DE VISITA =====
# Nome:  mm
# Idade:  12
# Altura:  12.0
# Cidade:  wsdf
# Hobby:  sdf

# %% [markdown]
# # Nova seção

# %%
numerox = 10
numeroy = 3

soma = numerox + numeroy
subtracao = numerox - numeroy
multiplicacao = numerox * numeroy
divisao = numerox / numeroy
resto = numerox % numerox
potencia = numerox ** numeroy

print("Soma: ", soma, "\nSubitração: ", subitracao, "\nMultiplicação: " multiplicacao, "\nDivisão: ", divisao, "\nResto: ", resto, "\nPotência: ", potencia)
